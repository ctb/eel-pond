# %%
# %pylab inline
DATA='../data/'
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import csv
best_matches = csv.DictReader(open(DATA + 'goi.x.lamp3.best_matches.tsv'), delimiter='\t')
total_matches = csv.DictReader(open(DATA + 'goi.x.lamp3.total_matches.tsv'), delimiter='\t')

# %%
best_matches = [ float(b['percent matched letters']) for b in best_matches ]

# %%
h = hist(best_matches, bins=20, normed=True, cumulative=True)
title('Cumulative dist of percent matched letters, for all matches')
xlabel('Fraction of sequences that match at that percent or lower')

print h
# Out:
# (array([ 0.6851851 ,  1.14197516,  1.14197516,  0.22839503,  1.37037019,
#         1.14197516,  0.45679006,  1.59876522,  0.91358013,  1.82716026,
#         1.59876522,  0.91358013,  1.14197516,  1.14197516,  0.45679006,
#         0.6851851 ,  0.22839503,  1.14197516,  1.82716026,  2.96913541]), array([ 0.106858  ,  0.15108405,  0.1953101 ,  0.23953615,  0.2837622 ,
#         0.32798825,  0.3722143 ,  0.41644035,  0.4606664 ,  0.50489245,
#         0.5491185 ,  0.59334455,  0.6375706 ,  0.68179665,  0.7260227 ,
#         0.77024875,  0.8144748 ,  0.85870085,  0.9029269 ,  0.94715295,
#         0.991379  ]), <a list of 20 Patch objects>)

# %%
total_matches = [ float(b['percent matched letters']) for b in total_matches ]

# %%
hist(total_matches, bins=20, cumulative=True, normed=True)
title('Cumulative dist of percent matched letters, for all matches')
xlabel('Fraction of sequences that match at that percent or lower')
